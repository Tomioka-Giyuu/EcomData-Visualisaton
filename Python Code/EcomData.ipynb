# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("filenamecsv")
# Out:
# <ipython-input-18-507f0e62bfd7>:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/drive/MyDrive/Data Science[Codes]/Projects/Datasets/Amazon Sale Report.csv")

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.count()
# Out:
# index                 128975
# Order ID              128975
# Date                  128975
# Status                128975
# Fulfilment            128975
# Sales Channel         128975
# ship-service-level    128975
# Style                 128975
# SKU                   128975
# Category              128975
# Size                  128975
# ASIN                  128975
# Courier Status        122103
# Qty                   128975
# currency              121180
# Amount                121180
# ship-city             128942
# ship-state            128942
# ship-postal-code      128942
# ship-country          128942
# promotion-ids          79822
# B2B                   128975
# fulfilled-by           39277
# Unnamed: 22            79925
# dtype: int64

# %%
df.nunique()
# Out:
# index                 128975
# Order ID              120378
# Date                      91
# Status                    13
# Fulfilment                 2
# Sales Channel              2
# ship-service-level         2
# Style                   1377
# SKU                     7195
# Category                   9
# Size                      11
# ASIN                    7190
# Courier Status             3
# Qty                       10
# currency                   1
# Amount                  1410
# ship-city               8955
# ship-state                69
# ship-postal-code        9459
# ship-country               1
# promotion-ids           5787
# B2B                        2
# fulfilled-by               1
# Unnamed: 22                1
# dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.drop(['Order ID','Courier Status','Date','ship-country','ship-postal-code','promotion-ids','SKU','Unnamed: 22','currency','Style','ASIN','Qty','fulfilled-by'],inplace=True, axis=1)

# %%
df.head()
# Out:
#    index                        Status Fulfilment Sales Channel   \
# 0      0                     Cancelled   Merchant      Amazon.in
# 1      1  Shipped - Delivered to Buyer   Merchant      Amazon.in
# 2      2                       Shipped     Amazon      Amazon.in
# 3      3                     Cancelled   Merchant      Amazon.in
# 4      4                       Shipped     Amazon      Amazon.in
#
#   ship-service-level       Category Size  Amount    ship-city   ship-state  \
# 0           Standard            Set    S  647.62       MUMBAI  MAHARASHTRA
# 1           Standard          kurta  3XL  406.00    BENGALURU    KARNATAKA
# 2          Expedited          kurta   XL  329.00  NAVI MUMBAI  MAHARASHTRA
# 3           Standard  Western Dress    L  753.33   PUDUCHERRY   PUDUCHERRY
# 4          Expedited            Top  3XL  574.00      CHENNAI   TAMIL NADU
#
#      B2B
# 0  False
# 1  False
# 2   True
# 3  False
# 4  False

# %%
df.isnull().sum()
# Out:
# index                    0
# Status                   0
# Fulfilment               0
# Sales Channel            0
# ship-service-level       0
# Category                 0
# Size                     0
# Amount                7795
# ship-city               33
# ship-state              33
# B2B                      0
# dtype: int64

# %%
df['Status'].nunique()
# Out:
# 13

# %%
df['Status'].value_counts()
# Out:
# Shipped                          77804
# Shipped - Delivered to Buyer     28769
# Cancelled                        18332
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: Status, dtype: int64

# %%
from google.colab import files

# %%
df.to_csv('df.csv', index=False)

# Download the file
files.download('df.csv')
